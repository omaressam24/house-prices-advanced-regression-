# %% [markdown]
# # Goal
# It is your job to predict the sales price for each house. For each Id in the test set, you must predict the value of the SalePrice variable.
#
# # Metric
# Submissions are evaluated on Root-Mean-Squared-Error (RMSE) between the logarithm of the predicted value and the logarithm of the observed sales price. (Taking logs means that errors in predicting expensive houses and cheap houses will affect the result equally.)

# %% [markdown]
# # Import Library & Read Dataset

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
sns.set(rc={'figure.figsize':(25,15)})

# %% [markdown]
# ## Read and Explore Data

# %%
df_train = pd.read_csv('house-prices-advanced-regression-techniques/train.csv')
df_test = pd.read_csv('house-prices-advanced-regression-techniques/test.csv')

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df_train.describe()
# Out:
#            SalePrice  LotFrontage  OverallQual    YearBuilt  YearRemodAdd  \
# count    1168.000000  1168.000000  1168.000000  1168.000000   1168.000000
# mean   181441.541952    70.289247     6.121575  1970.965753   1984.897260
# std     77263.583862    22.463601     1.367619    30.675495     20.733955
# min     34900.000000    21.000000     1.000000  1872.000000   1950.000000
# 25%    130000.000000    60.000000     5.000000  1953.000000   1966.000000
# 50%    165000.000000    70.049958     6.000000  1972.000000   1994.000000
# 75%    214925.000000    79.000000     7.000000  2001.000000   2004.000000
# max    745000.000000   313.000000    10.000000  2010.000000   2010.000000
#
#          GrLivArea   GarageCars   GarageArea     FullBath
# count  1168.000000  1168.000000  1168.000000  1168.000000
# mean   1527.401541     1.781678   476.273973     1.577055
# std     524.432686     0.740161   211.095373     0.546912
# min     334.000000     0.000000     0.000000     0.000000
# ...

# %%
sns.heatmap(df_train.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
df_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
cols = ['SalePrice','LotFrontage','OverallQual', 'YearBuilt', 'YearRemodAdd','GrLivArea','GarageCars', 'GarageArea','FullBath']

# %%
df_train = df_train.loc[:,cols]

# %%
df_train.head()
# Out:
#    SalePrice  LotFrontage  OverallQual  YearBuilt  YearRemodAdd  GrLivArea  \
# 0     208500         65.0            7       2003          2003       1710
# 1     181500         80.0            6       1976          1976       1262
# 2     223500         68.0            7       2001          2002       1786
# 3     140000         60.0            7       1915          1970       1717
# 4     250000         84.0            8       2000          2000       2198
#
#    GarageCars  GarageArea  FullBath
# 0           2         548         2
# 1           2         460         2
# 2           2         608         2
# 3           3         642         1
# 4           3         836         2

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SalePrice     1460 non-null   int64
#  1   LotFrontage   1201 non-null   float64
#  2   OverallQual   1460 non-null   int64
#  3   YearBuilt     1460 non-null   int64
#  4   YearRemodAdd  1460 non-null   int64
#  5   GrLivArea     1460 non-null   int64
#  6   GarageCars    1460 non-null   int64
#  7   GarageArea    1460 non-null   int64
#  8   FullBath      1460 non-null   int64
# dtypes: float64(1), int64(8)
# memory usage: 102.8 KB

# %%
df_train.isnull().sum() / len(df_train) *100
# Out:
# SalePrice        0.000000
# LotFrontage     17.739726
# OverallQual      0.000000
# YearBuilt        0.000000
# YearRemodAdd     0.000000
# GrLivArea        0.000000
# GarageCars       0.000000
# GarageArea       0.000000
# FullBath         0.000000
# dtype: float64

# %%
(df_train['SalePrice'] < 0).sum()
# Out:
# 0

# %%
(df_train['GrLivArea'] <=0).sum()
# Out:
# 0

# %%
(df_train['FullBath'] <0).sum()
# Out:
# 0

# %%
(df_train['GrLivArea'] <=0).sum()
# Out:
# 0

# %%
(df_train['GarageArea'] <0).sum()
# Out:
# 0

# %%
sns.boxplot(data = df_train, y = 'SalePrice')
# Out:
# <AxesSubplot:ylabel='SalePrice'>

# %%
sns.distplot(df_train['LotFrontage'])
# Out:
# C:\Users\oessa\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='LotFrontage', ylabel='Density'>

# %%
sns.pairplot(data = df_train)

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy ='mean')
df_train['LotFrontage'] = imputer.fit_transform(df_train[['LotFrontage']])
imputer.statistics_
# Out:
# array([70.04995837])

# %%
df_train.isnull().sum()
# Out:
# SalePrice       0
# LotFrontage     0
# OverallQual     0
# YearBuilt       0
# YearRemodAdd    0
# GrLivArea       0
# GarageCars      0
# GarageArea      0
# FullBath        0
# dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SalePrice     1460 non-null   int64
#  1   LotFrontage   1460 non-null   float64
#  2   OverallQual   1460 non-null   int64
#  3   YearBuilt     1460 non-null   int64
#  4   YearRemodAdd  1460 non-null   int64
#  5   GrLivArea     1460 non-null   int64
#  6   GarageCars    1460 non-null   int64
#  7   GarageArea    1460 non-null   int64
#  8   FullBath      1460 non-null   int64
# dtypes: float64(1), int64(8)
# memory usage: 102.8 KB

# %%
cols2 = ['LotFrontage','OverallQual', 'YearBuilt', 'YearRemodAdd','GrLivArea','GarageCars', 'GarageArea','FullBath']

# %%
df_test = df_test.loc[:,cols2]

# %%
from sklearn.model_selection import train_test_split
df_train, df_val = train_test_split(df_train, test_size = 0.2, random_state = 42)

# %%
df_train.shape
# Out:
# (1168, 9)

# %%
df_val.shape
# Out:
# (292, 9)

# %%
X_train = df_train.drop('SalePrice', axis = 1)
X_train.shape
# Out:
# (1168, 8)

# %%
y_train = df_train['SalePrice']

# %%
y_train.shape
# Out:
# (1168,)

# %%
X_val = df_val.drop('SalePrice', axis = 1)
y_val =df_val['SalePrice']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
scaled_X_train = scaler.transform(X_train)
scaled_X_val = scaler.transform(X_val)

# %%
scaled_X_train
# Out:
# array([[-0.01288179, -0.82044456, -0.45546896, ..., -1.05654384,
#         -0.86383727, -1.05556573],
#        [-0.5027726 , -0.08893368,  0.71860895, ...,  0.29509165,
#         -0.45626397,  0.7736639 ],
#        [-0.14648837, -0.82044456, -1.98829291, ..., -2.40817934,
#         -2.25716927, -1.05556573],
#        ...,
#        [-0.45823707, -0.82044456, -0.52069551, ...,  0.29509165,
#          0.45366713, -1.05556573],
#        [-0.68091471,  0.64257719, -1.72738671, ..., -1.05654384,
#         -1.23349678, -1.05556573],
#        [-0.76998577,  0.64257719,  1.17519481, ...,  1.64672715,
#          0.87071888,  0.7736639 ]])

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train,y_train)

predictions = model.predict(X_val)

# %%
model.score(X_train,y_train)
# Out:
# 0.7521541243495122

# %%
model.score(X_val,y_val)
# model.score(X_test,y_test)
# Out:
# 0.7737064564819649

# %%
X_train.columns
# Out:
# Index(['LotFrontage', 'OverallQual', 'YearBuilt', 'YearRemodAdd', 'GrLivArea',
#        'GarageCars', 'GarageArea', 'FullBath'],
#       dtype='object')

# %%
(y_train<0).sum()
# Out:
# 0

# %%
model2 = LinearRegression()
model2.fit(scaled_X_train, y_train)


model2.score(scaled_X_train, y_train)
# Out:
# 0.7521541243495121

# %%
model2.score(scaled_X_val, y_val)
# Out:
# 0.7737064564819645

# %%
from sklearn.metrics import mean_squared_error as mse

preds1 = model.predict(X_val)
preds2 = model2.predict(scaled_X_val)

# %%
rmse1 = mse(y_val, preds1) ** (1/2)

# %%
rmse1
# Out:
# 41662.276670432024

# %%
rmse2 = mse(y_val, preds1) ** (1/2)

# %%
rmse2
# Out:
# 41662.276670432024
